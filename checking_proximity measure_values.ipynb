# %% [markdown]
# **In this notebook, we compare our implementations with three tables from the 2024 paper**: *A New Proximity Metric Based on Optimality Conditions for Single and Multi-Objective Optimization: Method and Validation* by Mohammed Jameel and Mohamed Abouhawwash.
#
# **There are three notebooks related to the three tables as follows:**
#
# 1.  ZDT1 problem on page 18
# 2.  SRN problem on page 18
# 3.  ZDT1 problem in Table 2 and on page 6

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from pymoo.core.problem import Problem
from pymoo.optimize import minimize
from scipy.optimize import approx_fprime
from pbi_proximity_measure import pbi_kktpm
from apbi_proximity_measure import apbi_kktpm


# 1) Define the ZDT1 problem restricted to 2 variables
class ZDT1_2D(Problem):
    """
    ZDT1 problem restricted to 2 variables:
        Min f1 = x[0]
        Min f2 = (1 + 9*x[1]) * (1 - sqrt(x[0] / (1 + 9*x[1])))
        s.t. 0 <= x[0] <= 1, 0 <= x[1] <= 1
    """
    def __init__(self):
        super().__init__(
            n_var=2, 
            n_obj=2, 
            n_constr=0, 
            xl=np.array([0.0, 0.0]), 
            xu=np.array([1.0, 1.0])
        )

    def _evaluate(self, x, out, *args, **kwargs):
        # x shape is (n, 2)
        f1 = x[:, 0]
        g  = 1.0 + 9.0 * x[:, 1]
        f2 = g * (1 - np.sqrt(x[:, 0] / g))
        out["F"] = np.column_stack([f1, f2])

        g1 =   -x[:, 0] 
        g2 =   -x[:, 1] 
        g3 = +x[:, 0] - 1
        g4 = +x[:, 1] - 1

        out["G"] = np.column_stack([g1, g2, g3, g4])


def d1(x, w, r_star):
    X_batch = np.array([x])
    out = {}
    problem._evaluate(X_batch, out)
    F_x = out["F"][0]  # shape (2,) for 2 objectives
    w = np.array(w)
    w = w / np.linalg.norm(w)
    r_star = np.array(r_star)
    F_x = np.array(F_x)
    # d1: projection of (F(x) - r_star) onto w
    d1 = np.dot(F_x - r_star, w) / np.linalg.norm(w)
    return d1
    
def d2(x, w, r_star):
    X_batch = np.array([x])
    out = {}
    problem._evaluate(X_batch, out)
    F_x = out["F"][0]  # shape (2,) for 2 objectives
    w = np.array(w)
    w = w / np.linalg.norm(w)
    r_star = np.array(r_star)
    F_x = np.array(F_x)
    # d2: perpendicular distance from F(x) to the line L
    d1 = np.dot(F_x - r_star, w) / np.linalg.norm(w)
    beta = 10  # Higher values make approximation closer to the original norm
    diff_sq = (F_x - (r_star + (d1 * w)))**2
    d2_smooth = (1 / beta) * np.log(np.sum(np.exp(beta * diff_sq)))
    return d2_smooth
    
def evaluate_constraints(x, problem):
    """
    Evaluate constraints for a single solution x (which is 2D: shape (1, n_var)).
    Returns
    -------
    np.ndarray
        1D array of combined inequality constraints [g(x), h(x), -h(x)] if they exist.
        Empty array if no constraints exist.
    """
    out = {}
    problem._evaluate(x, out)
    # If out has "G", store it; else create empty array of shape (1, 0)
    g_arr = np.array(out["G"]) if "G" in out else np.empty((x.shape[0], 0))
    # If out has "H", store it; else create empty array
    h_arr = np.array(out["H"]) if "H" in out else np.empty((x.shape[0], 0))
    # Transform equality constraints H(x) = 0 into two inequalities: H(x) <= 0 and -H(x) <= 0
    if h_arr.size > 0:
        transformed_h = np.column_stack([h_arr, -h_arr])
    else:
        transformed_h = np.empty((x.shape[0], 0))
    # Combine G and transformed H
    if g_arr.size > 0 and transformed_h.size > 0:
        combined_constraints = np.column_stack([g_arr, transformed_h])
    elif g_arr.size > 0:
        combined_constraints = g_arr
    else:
        combined_constraints = transformed_h
    # If constraints exist, return the constraints of the first row; otherwise return empty
    if combined_constraints.size > 0:
        return combined_constraints[0]
    else:

        return np.empty((0,))
    
def single_constraint_func(x, idx, problem):
    """
    Evaluate the idx-th constraint for a single solution x. x is 1D list and problem is a pymoo problem instance.
    """
    # Make sure x is 2D for problem._evaluate
    X2D = x.reshape(1, -1)
    return evaluate_constraints(X2D, problem)[idx]



# 2) Define the PBI measure function:
#    PBI(x, w, r*, sigma) = d1 + sigma * d2
#    with d1 = ((F(x) - r*)^T w) / ||w||
#         d2 = || F(x) - (r* + d1 w) ||
def pbi_measure(x, problem, w, sigma, r_star):
    """
    x: 1D numpy array of decision variables (e.g., shape (2,))
    problem: a pymoo problem instance to evaluate F(x)
    w: weight vector
    sigma: the sigma parameter
    r_star: reference point (array-like)
    """
    # Evaluate the objectives F(x). For a single point, we can do this manually:
    # We'll create a batch of size 1 to pass into the problem.
    X_batch = np.array([x])
    out = {}
    problem._evaluate(X_batch, out)
    F_val = out["F"][0]  # shape (2,) for 2 objectives

    # Compute d1
    diff = (F_val - r_star)  # e.g., shape (2,)
    w_norm = np.linalg.norm(w)
    d1 = abs(np.dot(diff, w) / w_norm)

    # Compute d2
    delta = 1
    d2_vec = diff - d1 * w  # shape (2,)
    d2 = np.linalg.norm(d2_vec)
    d2_smooth_pseudo_huber = np.sum(delta**2 * (np.sqrt(1.0 + (d2_vec / delta)**2) - 1.0))

    pbi_value = d1 + sigma * d2
    return pbi_value


X_batch = np.array([[0.347935, 0.0]])
out = {}
problem = ZDT1_2D()
problem._evaluate(X_batch, out)
F_val = out["F"][0]  # shape (2,) for 2 objectives

# 4) Instantiate the problem and define the needed parameters
zdt1_problem = ZDT1_2D()                 # Our custom 2D ZDT1 problem
w_special = np.array([0.46, 0.54])       # Special weight
sigma_val = 5.0                          # Sigma = 5
r_star = np.array([0,0])            # Reference point

# We create a small "phi_func" closure that uses the above parameters:
def phi_func_zdt1(x):
    return pbi_measure(x, zdt1_problem, w_special, sigma_val, r_star)

g_functions = []
for i in range(4):
    # Use default argument trick: i=i prevents late binding in lambda
    g_functions.append(lambda zz, i=i: single_constraint_func(zz, i, problem))

# 5) Evaluate the six sample points from Table 9
points_zdt1 = {
    "A": np.array([0.347935, 0.000000]),
    "B": np.array([0.360000, 0.003835]),
    "C": np.array([0.450000, 0.032580]),
    "D": np.array([0.520000, 0.054950]),
    "E": np.array([0.600000, 0.080500]),
    "F": np.array([0.760000, 0.131580]),
}
results = []
data = []
print("ZDT1 (2D) APBI-KKTPM Tests\n---------------------------")
for label, x_val in points_zdt1.items():
    epsilon_A = apbi_kktpm(x_val, phi_func_zdt1, g_functions, implementation="paper_version")
    epsilon_A_updated = apbi_kktpm(x_val, phi_func_zdt1, g_functions, implementation="complicate_linear_system")
    if epsilon_A is None:
        epsilon_A = -1
    if epsilon_A_updated is None:
        epsionm_A_updated = -1

    epsilon_pbi = pbi_kktpm(x_val, phi_func_zdt1, g_functions)

    if epsilon_pbi is None:
        epsilon_pbi = -1

    # Calculate the gradients of d1 and d2
    grad_d1 = approx_fprime(x_val, lambda x: d1(x,w_special, r_star), epsilon=1e-6)
    grad_d2 = approx_fprime(x_val, lambda x: d2(x,w_special, r_star), epsilon=1e-6)


    X_batch = np.array([x_val])
    out = {}
    zdt1_problem._evaluate(X_batch, out)
    f_val = out["F"][0]
    f1, f2 = f_val[0], f_val[1]

    data.append({
        "Point": label,
        "x": x_val,
        "f1": f1,
        "f2": f2,
        "APBI-KKTPM": epsilon_A,
        "APBI-KKTPM Updated": epsilon_A_updated,
        "EPBI-KKTPM": epsilon_pbi
    })
    results.append((label, x_val,f1, f2, epsilon_A, epsilon_A_updated, epsilon_pbi))
    

df = pd.DataFrame(data)

# Plot the results.


for label, x_val,f1, f2, epsilon_A, epsilon_A_updated, epsilon_pbi in results:
    print(f"Point {label} -> x={x_val}, f1 = {f1:.3f}, f2 = {f2:.3f} APBI-KKTPM={epsilon_A:.3f} APBI-KKTPM Updated={epsilon_A_updated:.3f} PBI-KKTPM={epsilon_pbi:.3f}")

points = [item[0] for item in results]  # label
epsilon_A_vals = [item[4] for item in results]
epsilon_A_updated_vals = [item[5] for item in results]
epsilon_pbi_vals = [item[6] for item in results]

x = np.arange(len(points))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width, epsilon_A_vals, width, label='APBI-KKTPM')
rects2 = ax.bar(x,        epsilon_A_updated_vals, width, label='APBI-KKTPM Updated')
rects3 = ax.bar(x + width, epsilon_pbi_vals, width, label='PBI-KKTPM')

ax.set_ylabel('KKTPM Value')
ax.set_xticks(x)
ax.set_xticklabels(points, rotation=45)
ax.legend()
ax.set_title('Comparison of KKTPM values across points')

plt.tight_layout()
plt.show()
# Out:
# (CVXPY) Mar 20 05:34:10 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Mar 20 05:34:10 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')
# ZDT1 (2D) APBI-KKTPM Tests
# ---------------------------
# Walue of phi function:  1.3194333715912103
# The solver could not find an optimal solution.
# Failed to solve the linear system. We now try with quadratic system.
# Walue of phi function:  1.3194333715912103
# The shape of LHS is:  (5, 5)
# The value of S is:  [0]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3, 4]
# The value of LHS is:  [[ 1.44879861e+02  3.82132401e-02 -1.19949323e+01 -3.82132401e-02
#    1.19949323e+01]
#  [ 3.82132401e-02  1.12105876e+00  0.00000000e+00 -7.73123764e-01
#    3.47935000e-01]
#  [-1.19949323e+01  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   -1.00000000e+00]
#  [-3.82132401e-02 -7.73123764e-01  0.00000000e+00  1.42518876e+00
#    6.52065000e-01]
#  [ 1.19949323e+01  3.47935000e-01 -1.00000000e+00  6.52065000e-01
#    2.00000000e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930977294430047
# Condition is satisfied
# The value of epsilon_FSk is:  0.0014581224952538996
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930976660660995
# Condition is not satisfied
# Condition is satisfied
# The value of epsilon_FSk is:  0.0014581224952701088
# Grad phi: [-0.03821324 11.9949323 ]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.347935, -0.0, -0.652065, -1.0]
# Optimal u: [-3.93644025e-18  1.19949323e+01  2.01003305e-03  4.21418680e-17]
# Optimal eps_k: 0.0013106722010782425
# Walue of phi function:  1.36497155884043
# The solver could not find an optimal solution.
# Failed to solve the linear system. We now try with quadratic system.
# Walue of phi function:  1.36497155884043
# The shape of LHS is:  (5, 5)
# The value of S is:  [0]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3, 4]
# The value of LHS is:  [[ 1.44646518e+02  3.51129965e-02 -1.19852111e+01 -3.51129965e-02
#    1.19852111e+01]
#  [ 3.51129965e-02  1.12960000e+00  1.38060000e-03 -7.69600000e-01
#    3.58619400e-01]
#  [-1.19852111e+01  1.38060000e-03  1.00001471e+00  2.45440000e-03
#   -9.96179707e-01]
#  [-3.51129965e-02 -7.69600000e-01  2.45440000e-03  1.40960000e+00
#    6.37545600e-01]
#  [ 1.19852111e+01  3.58619400e-01 -9.96179707e-01  6.37545600e-01
#    1.99234471e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930865947167248
# Condition is not satisfied
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930865407642087
# Condition is not satisfied
# Grad phi: [-0.035113   11.98521109]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.36, -0.003835, -0.64, -0.996165]
# Optimal u: [9.49975624e-16 1.17756244e+01 3.89034669e-16 2.17424304e-16]
# Optimal eps_k: 0.04515951938961175
# Walue of phi function:  1.7063160032102838
# The solver could not find an optimal solution.
# Failed to solve the linear system. We now try with quadratic system.
# Walue of phi function:  1.7063160032102838
# The shape of LHS is:  (5, 5)
# The value of S is:  [0]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3, 4]
# The value of LHS is:  [[ 1.44733517e+02  3.62934762e-02 -1.19888365e+01 -3.62934762e-02
#    1.19888365e+01]
#  [ 3.62934762e-02  1.20250000e+00  1.46610000e-02 -7.52500000e-01
#    4.35339000e-01]
#  [-1.19888365e+01  1.46610000e-02  1.00106146e+00  1.79190000e-02
#   -9.68481456e-01]
#  [-3.62934762e-02 -7.52500000e-01  1.79190000e-02  1.30250000e+00
#    5.32081000e-01]
#  [ 1.19888365e+01  4.35339000e-01 -9.68481456e-01  5.32081000e-01
#    1.93590146e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930907503594775
# Condition is not satisfied
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930906908697357
# Grad phi: [-0.03629348 11.98883646]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.45, -0.03258, -0.55, -0.96742]
# Optimal u: [-5.54929659e-16  1.13809915e+01 -6.28603741e-17  2.02638634e-16]
# Optimal eps_k: 0.3707927033973263
# Walue of phi function:  1.971959385435308
# The solver could not find an optimal solution.
# Failed to solve the linear system. We now try with quadratic system.
# Walue of phi function:  1.971959385435308
# The shape of LHS is:  (5, 5)
# The value of S is:  [0]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3, 4]
# The value of LHS is:  [[ 1.44895655e+02  3.84623680e-02 -1.19955898e+01 -3.84623680e-02
#    1.19955898e+01]
#  [ 3.84623680e-02  1.27040000e+00  2.85740000e-02 -7.50400000e-01
#    4.91426000e-01]
#  [-1.19955898e+01  2.85740000e-02  1.00301950e+00  2.63760000e-02
#   -9.48069502e-01]
#  [-3.84623680e-02 -7.50400000e-01  2.63760000e-02  1.23040000e+00
#    4.53624000e-01]
#  [ 1.19955898e+01  4.91426000e-01 -9.48069502e-01  4.53624000e-01
#    1.89311950e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930984817966519
# Condition is not satisfied
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930984138037465
# Grad phi: [-0.03846237 11.99558984]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.52, -0.05495, -0.48, -0.94505]
# Optimal u: [ 1.96028446e-16  1.12116258e+01 -8.35210259e-18  1.69807531e-16]
# Optimal eps_k: 0.6160788392321658
# Walue of phi function:  2.2753633843695242
# The solver could not find an optimal solution.
# Failed to solve the linear system. We now try with quadratic system.
# Walue of phi function:  2.2753633843695242
# The shape of LHS is:  (5, 5)
# The value of S is:  [0]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3, 4]
# The value of LHS is:  [[ 1.44911765e+02  3.86871255e-02 -1.19962606e+01 -3.86871255e-02
#    1.19962606e+01]
#  [ 3.86871255e-02  1.36000000e+00  4.83000000e-02 -7.60000000e-01
#    5.51700000e-01]
#  [-1.19962606e+01  4.83000000e-02  1.00648025e+00  3.22000000e-02
#   -9.25980250e-01]
#  [-3.86871255e-02 -7.60000000e-01  3.22000000e-02  1.16000000e+00
#    3.67800000e-01]
#  [ 1.19962606e+01  5.51700000e-01 -9.25980250e-01  3.67800000e-01
#    1.84548025e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930992490307414
# Condition is not satisfied
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930991791129143
# Grad phi: [-0.03868713 11.99626058]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.6, -0.0805, -0.4, -0.9195]
# Optimal u: [-6.14488387e-17  1.10537480e+01 -1.45931378e-16  6.78553790e-17]
# Optimal eps_k: 0.8898267115196917
# Walue of phi function:  2.881931495708497
# The solver could not find an optimal solution.
# Failed to solve the linear system. We now try with quadratic system.
# Walue of phi function:  2.881931495708497
# The shape of LHS is:  (5, 5)
# The value of S is:  [0]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 3, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 3, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 2, 3, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# The shape of LHS is:  (5, 5)
# The value of S is:  [0, 1, 2, 3, 4]
# The value of LHS is:  [[ 1.44810338e+02  3.73526770e-02 -1.19920366e+01 -3.73526770e-02
#    1.19920366e+01]
#  [ 3.73526770e-02  1.57760000e+00  1.00000800e-01 -8.17600000e-01
#    6.59999200e-01]
#  [-1.19920366e+01  1.00000800e-01  1.01731330e+00  3.15792000e-02
#   -8.85733296e-01]
#  [-3.73526770e-02 -8.17600000e-01  3.15792000e-02  1.05760000e+00
#    2.08420800e-01]
#  [ 1.19920366e+01  6.59999200e-01 -8.85733296e-01  2.08420800e-01
#    1.75415330e+00]]
# The value of RHS is:  [1. 0. 0. 0. 0.]
# The solver could not find an optimal solution.
# Condition is satisfied
# The value of epsilon_FSk is:  0.993094415660616
# Condition is satisfied
# The value of epsilon_FSk is:  0.5077851505698117
# Condition is satisfied
# The value of epsilon_FSk is:  0.9930943493232277
# Grad phi: [-0.03735268 11.99203663]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.76, -0.13158, -0.24, -0.86842]
# Optimal u: [ 2.27286652e-16  1.08005099e+01  6.92544635e-17 -2.42193075e-16]
# Optimal eps_k: 1.4211310962771275
# Point A -> x=[0.347935 0.      ], f1 = 0.348, f2 = 0.410 APBI-KKTPM=-1.000 APBI-KKTPM Updated=0.001 PBI-KKTPM=0.001
# Point B -> x=[0.36     0.003835], f1 = 0.360, f2 = 0.424 APBI-KKTPM=-1.000 APBI-KKTPM Updated=0.022 PBI-KKTPM=0.045
# Point C -> x=[0.45    0.03258], f1 = 0.450, f2 = 0.530 APBI-KKTPM=-1.000 APBI-KKTPM Updated=0.169 PBI-KKTPM=0.371
# Point D -> x=[0.52    0.05495], f1 = 0.520, f2 = 0.613 APBI-KKTPM=-1.000 APBI-KKTPM Updated=0.266 PBI-KKTPM=0.616
# Point E -> x=[0.6    0.0805], f1 = 0.600, f2 = 0.707 APBI-KKTPM=-1.000 APBI-KKTPM Updated=0.359 PBI-KKTPM=0.890
# Point F -> x=[0.76    0.13158], f1 = 0.760, f2 = 0.896 APBI-KKTPM=-1.000 APBI-KKTPM Updated=0.508 PBI-KKTPM=1.421

# %%
# This is the case for the SRN problem


class CustomSRN(Problem):

    def __init__(self):
        super().__init__(n_var=2, n_obj=2, n_constr=2, xl=np.array([-20, -20]), xu=np.array([20, 20]))

    def _evaluate(self, x, out, *args, **kwargs):
        # Objective functions
        f1 = (x[:, 0] - 2) ** 2 + (x[:, 1] - 1) ** 2 + 2
        f2 = 9 * x[:, 0] - (x[:, 1] - 1) ** 2

        # Constraints
        g1 = -225 + x[:, 0] ** 2 + x[:, 1] ** 2  # g1(x) <= 0
        g2 = (x[:, 0] - 3 * x[:, 1]) + 10 # g2(x) <= 0

        out["F"] = np.column_stack([f1, f2])
        out["G"] = np.column_stack([g1, g2])  # Constraints



X_batch = np.array([[0.347935, 0.0]])
out = {}
problem_srn = CustomSRN() # Our custom 2D ZDT1 problem
problem_srn._evaluate(X_batch, out)
F_val = out["F"][0]  # shape (2,) for 2 objectives
print("F_val2", F_val)

# 4) Instantiate the problem and define the needed parameters          
w_special = np.array([0.5, 0.5])       # Special weight
sigma_val = 5.0                          # Sigma = 5
r_star = np.array([0, -250])            # Reference point

# We create a small "phi_func" closure that uses the above parameters:
def phi_func_srn(x):
    return pbi_measure(x, problem_srn, w_special, sigma_val, r_star)

g_functions = []
for i in range(problem.n_constr):
    # Use default argument trick: i=i prevents late binding in lambda
    g_functions.append(lambda zz, i=i: single_constraint_func(zz, i, problem))

# 5) Evaluate the six sample points from Table 9
points_srn = {
    "A": np.array([-2.5, 11.130391]),
    "B": np.array([-3.0, 10.899495]),
    "C": np.array([-4.791288, 9.909556]),
    "D": np.array([-8.0, 7.1644140]),
    "E": np.array([-9.588723, 4.701552]),
    "F": np.array([7.0, 12.958261]),
}
results = []
data = []
print("SRN APBI-KKTPM Tests\n---------------------------")
for label, x_val in points_srn.items():
    epsilon_A = apbi_kktpm(x_val, phi_func_srn, g_functions, implementation="paper_version")
    epsilon_A_updated = apbi_kktpm(x_val, phi_func_srn, g_functions, implementation="complicate_linear_system")
    if epsilon_A is None:
        epsilon_A = -1
    if epsilon_A_updated is None:
        epsilon_A_updated = -1

    epsilon_pbi = pbi_kktpm(x_val, phi_func_srn, g_functions)

    if epsilon_pbi is None:
        epsilon_pbi = -1

    # Calculate the gradients of d1 and d2
    grad_d1 = approx_fprime(x_val, lambda x: d1(x,w_special, r_star), epsilon=1e-6)
    grad_d2 = approx_fprime(x_val, lambda x: d2(x,w_special, r_star), epsilon=1e-6)




    X_batch = np.array([x_val])
    out = {}
    problem._evaluate(X_batch, out)
    f_val = out["F"][0]
    f1, f2 = f_val[0], f_val[1]

    data.append({
        "Point": label,
        "x": x_val,
        "f1": f1,
        "f2": f2,
        "APBI-KKTPM": epsilon_A,
        "APBI-KKTPM Updated": epsilon_A_updated,
        "EPBI-KKTPM": epsilon_pbi
    })

    results.append((label, x_val,f1, f2, epsilon_A, epsilon_A_updated, epsilon_pbi))
    

data = []
for label, x_val,f1, f2, epsilon_A, epsilon_A_updated, epsilon_pbi in results:
    print(f"Point {label} -> x={x_val}, f1 = {f1}, f2 = {f2} APBI-KKTPM={epsilon_A} APBI-KKTPM Updated={epsilon_A_updated} PBI-KKTPM={epsilon_pbi}")


df = pd.DataFrame(data)


#Visualizing the results

points = [item[0] for item in results]  # label
epsilon_A_vals = [item[4] for item in results]
epsilon_A_updated_vals = [item[5] for item in results]
epsilon_pbi_vals = [item[6] for item in results]

x = np.arange(len(points))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width, epsilon_A_vals, width, label='APBI-KKTPM')
rects2 = ax.bar(x,        epsilon_A_updated_vals, width, label='APBI-KKTPM Updated')
rects3 = ax.bar(x + width, epsilon_pbi_vals, width, label='PBI-KKTPM')

ax.set_ylabel('KKTPM Value')
ax.set_xticks(x)
ax.set_xticklabels(points, rotation=45)
ax.legend()
ax.set_title('Comparison of KKTPM values across points')

plt.tight_layout()
plt.show()
# Out:
# F_val2 [5.72931876 2.131415  ]
# SRN APBI-KKTPM Tests
# ---------------------------
# Walue of phi function:  435.2245116111107
# Condition is satisfied
# The value of epsilon_FSk is:  5.354907385290986e-07
# Walue of phi function:  435.2245116111107
# The shape of LHS is:  (2, 2)
# The value of S is:  [0]
# The value of LHS is:  [[1.00000054 0.        ]
#  [0.         1.        ]]
# The value of RHS is:  [1. 0.]
# The shape of LHS is:  (2, 2)
# The value of S is:  [0, 1]
# The value of LHS is:  [[1.00000054 0.        ]
#  [0.         1.        ]]
# The value of RHS is:  [1. 0.]
# Condition is satisfied
# The value of epsilon_FSk is:  5.354907385290986e-07
# Condition is satisfied
# The value of epsilon_FSk is:  5.354907385290986e-07
# Grad phi: [ 0.00031957 -0.0006583 ]
# Grad g: []
# g_vals: []
# Optimal u: []
# Optimal eps_k: 5.354910251886835e-07
# Walue of phi function:  435.66017177982144
# Condition is satisfied
# The value of epsilon_FSk is:  0.752277081454472
# Walue of phi function:  435.66017177982144
# The shape of LHS is:  (2, 2)
# The value of S is:  [0]
# The value of LHS is:  [[4.0367682 0.       ]
#  [0.        1.       ]]
# The value of RHS is:  [1. 0.]
# The shape of LHS is:  (2, 2)
# The value of S is:  [0, 1]
# The value of LHS is:  [[4.0367682 0.       ]
#  [0.        1.       ]]
# The value of RHS is:  [1. 0.]
# Condition is satisfied
# The value of epsilon_FSk is:  0.752277081454472
# Condition is satisfied
# The value of epsilon_FSk is:  0.752277081454472
# Grad phi: [-1.74263255e+00  4.27462510e-05]
# Grad g: []
# g_vals: []
# Optimal u: []
# Optimal eps_k: 3.036768200017053
# Walue of phi function:  444.37337673355165
# Condition is satisfied
# The value of epsilon_FSk is:  0.9845758428560429
# Walue of phi function:  444.37337673355165
# The shape of LHS is:  (2, 2)
# The value of S is:  [0]
# The value of LHS is:  [[64.83336436  0.        ]
#  [ 0.          1.        ]]
# The value of RHS is:  [1. 0.]
# The shape of LHS is:  (2, 2)
# The value of S is:  [0, 1]
# The value of LHS is:  [[64.83336436  0.        ]
#  [ 0.          1.        ]]
# The value of RHS is:  [1. 0.]
# Condition is satisfied
# The value of epsilon_FSk is:  0.9845758428560429
# Condition is satisfied
# The value of epsilon_FSk is:  0.9845758428560429
# Grad phi: [-7.98957620e+00  6.03751005e-03]
# Grad g: []
# g_vals: []
# Optimal u: []
# Optimal eps_k: 63.83336435608689
# Walue of phi function:  487.9393923933999
# Condition is satisfied
# The value of epsilon_FSk is:  0.9972859394630054
# Walue of phi function:  487.9393923933999
# The shape of LHS is:  (2, 2)
# The value of S is:  [0]
# The value of LHS is:  [[368.4516194   0.       ]
#  [  0.          1.       ]]
# The value of RHS is:  [1. 0.]
# The shape of LHS is:  (2, 2)
# The value of S is:  [0, 1]
# The value of LHS is:  [[368.4516194   0.       ]
#  [  0.          1.       ]]
# The value of RHS is:  [1. 0.]
# Condition is satisfied
# The value of epsilon_FSk is:  0.9972859394630054
# Condition is satisfied
# The value of epsilon_FSk is:  0.9972859394630054
# Grad phi: [-1.91690276e+01  1.30739863e-05]
# Grad g: []
# g_vals: []
# Optimal u: []
# Optimal eps_k: 367.45161941330883
# Walue of phi function:  522.7921952804109
# Condition is satisfied
# The value of epsilon_FSk is:  0.998364392906428
# Walue of phi function:  522.7921952804109
# The shape of LHS is:  (2, 2)
# The value of S is:  [0]
# The value of LHS is:  [[611.39377784   0.        ]
#  [  0.           1.        ]]
# The value of RHS is:  [1. 0.]
# The shape of LHS is:  (2, 2)
# The value of S is:  [0, 1]
# The value of LHS is:  [[611.39377784   0.        ]
#  [  0.           1.        ]]
# The value of RHS is:  [1. 0.]
# Condition is satisfied
# The value of epsilon_FSk is:  0.998364392906428
# Condition is satisfied
# The value of epsilon_FSk is:  0.998364392906428
# Grad phi: [-2.47061486e+01 -6.25277607e-06]
# Grad g: []
# g_vals: []
# Optimal u: []
# Optimal eps_k: 610.3937778117667
# Walue of phi function:  592.4978336205597
# Condition is satisfied
# The value of epsilon_FSk is:  0.9990886586587057
# Walue of phi function:  592.4978336205597
# The shape of LHS is:  (2, 2)
# The value of S is:  [0]
# The value of LHS is:  [[1.0972837e+03 0.0000000e+00]
#  [0.0000000e+00 1.0000000e+00]]
# The value of RHS is:  [1. 0.]
# The shape of LHS is:  (2, 2)
# The value of S is:  [0, 1]
# The value of LHS is:  [[1.0972837e+03 0.0000000e+00]
#  [0.0000000e+00 1.0000000e+00]]
# The value of RHS is:  [1. 0.]
# Condition is satisfied
# The value of epsilon_FSk is:  0.9990886586587057
# Condition is satisfied
# The value of epsilon_FSk is:  0.9990886586587057
# Grad phi: [3.31101752e+01 6.13908924e-05]
# Grad g: []
# g_vals: []
# Optimal u: []
# Optimal eps_k: 1096.2837011648005
# Point A -> x=[-2.5      11.130391], f1 = -2.5, f2 = nan APBI-KKTPM=5.354907385290986e-07 APBI-KKTPM Updated=5.354907385290986e-07 PBI-KKTPM=5.354910251886835e-07
# Point B -> x=[-3.       10.899495], f1 = -3.0, f2 = nan APBI-KKTPM=0.752277081454472 APBI-KKTPM Updated=0.752277081454472 PBI-KKTPM=3.036768200017053
# Point C -> x=[-4.791288  9.909556], f1 = -4.791288, f2 = nan APBI-KKTPM=0.9845758428560429 APBI-KKTPM Updated=0.9845758428560429 PBI-KKTPM=63.83336435608689
# Point D -> x=[-8.        7.164414], f1 = -8.0, f2 = nan APBI-KKTPM=0.9972859394630054 APBI-KKTPM Updated=0.9972859394630054 PBI-KKTPM=367.45161941330883
# Point E -> x=[-9.588723  4.701552], f1 = -9.588723, f2 = nan APBI-KKTPM=0.998364392906428 APBI-KKTPM Updated=0.998364392906428 PBI-KKTPM=610.3937778117667
# Point F -> x=[ 7.       12.958261], f1 = 7.0, f2 = 88.92991673518597 APBI-KKTPM=0.9990886586587057 APBI-KKTPM Updated=0.9990886586587057 PBI-KKTPM=1096.2837011648005
# C:\Users\Lukag\AppData\Local\Temp\ipykernel_38596\2365018924.py:32: RuntimeWarning: invalid value encountered in sqrt
#   f2 = g * (1 - np.sqrt(x[:, 0] / g))
# C:\Users\Lukag\AppData\Local\Temp\ipykernel_38596\2365018924.py:69: RuntimeWarning: overflow encountered in exp
#   d2_smooth = (1 / beta) * np.log(np.sum(np.exp(beta * diff_sq)))
# c:\Users\Lukag\miniconda3\Lib\site-packages\scipy\optimize\_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0

# %%
# 1) Define the ZDT1 problem restricted to 2 variables
class ZDT1_2D(Problem):
    """
    ZDT1 problem restricted to 2 variables:
        Min f1 = x[0]
        Min f2 = (1 + 9*x[1]) * (1 - sqrt(x[0] / (1 + 9*x[1])))
        s.t. 0 <= x[0] <= 1, 0 <= x[1] <= 1
    """
    def __init__(self):
        super().__init__(
            n_var=2, 
            n_obj=2, 
            n_constr=0, 
            xl=np.array([0.0, 0.0]), 
            xu=np.array([1.0, 1.0])
        )

    def _evaluate(self, x, out, *args, **kwargs):
        # x shape is (n, 2)
        f1 = x[:, 0]
        g  = 1.0 + 9.0 * x[:, 1]
        f2 = g * (1 - np.sqrt(x[:, 0] / g))
        out["F"] = np.column_stack([f1, f2])

        g1 =   -x[:, 0] 
        g2 =   -x[:, 1] 
        g3 = +x[:, 0] - 1
        g4 = +x[:, 1] - 1

        out["G"] = np.column_stack([g1, g2, g3, g4])

def evaluate_constraints(x, problem):
    """
    Evaluate constraints for a single solution x (which is 2D: shape (1, n_var)).
    Returns
    -------
    np.ndarray
        1D array of combined inequality constraints [g(x), h(x), -h(x)] if they exist.
        Empty array if no constraints exist.
    """
    out = {}
    problem._evaluate(x, out)
    # If out has "G", store it; else create empty array of shape (1, 0)
    g_arr = np.array(out["G"]) if "G" in out else np.empty((x.shape[0], 0))
    # If out has "H", store it; else create empty array
    h_arr = np.array(out["H"]) if "H" in out else np.empty((x.shape[0], 0))
    # Transform equality constraints H(x) = 0 into two inequalities: H(x) <= 0 and -H(x) <= 0
    if h_arr.size > 0:
        transformed_h = np.column_stack([h_arr, -h_arr])
    else:
        transformed_h = np.empty((x.shape[0], 0))
    # Combine G and transformed H
    if g_arr.size > 0 and transformed_h.size > 0:
        combined_constraints = np.column_stack([g_arr, transformed_h])
    elif g_arr.size > 0:
        combined_constraints = g_arr
    else:
        combined_constraints = transformed_h
    # If constraints exist, return the constraints of the first row; otherwise return empty
    if combined_constraints.size > 0:
        return combined_constraints[0]
    else:

        return np.empty((0,))
    
    
def single_constraint_func(x, idx, problem):
    """
    Evaluate the idx-th constraint for a single solution x. x is 1D list and problem is a pymoo problem instance.
    """
    # Make sure x is 2D for problem._evaluate
    X2D = x.reshape(1, -1)
    return evaluate_constraints(X2D, problem)[idx]



# 2) Define the PBI measure function:
#    PBI(x, w, r*, sigma) = d1 + sigma * d2
#    with d1 = ((F(x) - r*)^T w) / ||w||
#         d2 = || F(x) - (r* + d1 w) ||
def pbi_measure(x, problem, w, sigma, r_star):
    """
    x: 1D numpy array of decision variables (e.g., shape (2,))
    problem: a pymoo problem instance to evaluate F(x)
    w: weight vector
    sigma: the sigma parameter
    r_star: reference point (array-like)
    """
    # Evaluate the objectives F(x). For a single point, we can do this manually:
    # We'll create a batch of size 1 to pass into the problem.
    X_batch = np.array([x])
    out = {}
    problem._evaluate(X_batch, out)
    F_val = out["F"][0]  # shape (2,) for 2 objectives

    # Compute d1
    diff = (F_val - r_star)  # e.g., shape (2,)
    w_norm = np.linalg.norm(w)
    d1 = abs(np.dot(diff, w) / w_norm)

    #Print loggings
    print("F_val", F_val)
    print("diff", diff)
    print("w_norm", w_norm)
    print("d1", d1)


    # Compute d2
    delta = 1
    d2_vec = diff - d1 * w  # shape (2,)
    d2 = np.linalg.norm(d2_vec)
    d2_smooth_pseudo_huber = np.sum(delta**2 * (np.sqrt(1.0 + (d2_vec / delta)**2) - 1.0)) #This finction is meant to preserve smoothness and is different from the one in the article

    print("d2_vec", d2_vec)

    pbi_value = d1 + sigma * d2
    return pbi_value



# 4) Instantiate the problem and define the needed parameters
zdt1_problem = ZDT1_2D()                 # Our custom 2D ZDT1 problem
w_special = np.array([0,1])       # Special weight
sigma_val = 1                      # Sigma = 1
r_star = np.array([0,0])            # Reference point

# We create a small "phi_func" closure that uses the above parameters:
def phi_func_zdt1(x):
    return pbi_measure(x, zdt1_problem, w_special, sigma_val, r_star)

g_functions = []
for i in range(4):
    # Use default argument trick: i=i prevents late binding in lambda
    g_functions.append(lambda zz, i=i: single_constraint_func(zz, i, zdt1_problem))




# 6) Define the six points from Table 2.
# Table 2 points for ZDT1 (2D) are given in decision space.
points_table2 = {
    "A1": np.array([1e-6, 0.000000]),
    "B1": np.array([1e-6, 0.010000]),
    "C1": np.array([1e-6, 0.040000]),
    "D1": np.array([1e-6, 0.060000]),
    "E1": np.array([1e-6, 0.080000]),
    "F1": np.array([1e-6, 0.090000]),
}


# 7) Evaluate KKTPM measures on each point.
# We'll compute:
# - ASF-KKTPM (using apbi_kktpm with "paper_version" implementation)
# - AASF-KKTPM (using apbi_kktpm with "complicate_linear_system" implementation)
# - PBI-KKTPM (using pbi_kktpm)
results = []
data = []

print("ZDT1 (2D) Table 2 KKTPM Tests")
print("--------------------------------------")

for label, x_val in points_table2.items():
    # Compute APBI-KKTPM using two implementations:
    epsilon_A =  1 #apbi_kktpm(x_val, phi_func_zdt1, g_functions, implementation="paper_version")
    epsilon_A_updated = 1 #apbi_kktpm(x_val, phi_func_zdt1, g_functions, implementation="complicate_linear_system")
    if epsilon_A is None:
        epsilon_A = -1
    if epsilon_A_updated is None:
        epsilon_A_updated = -1

    epsilon_pbi = pbi_kktpm(x_val, phi_func_zdt1, g_functions, 1e-6)
    if epsilon_pbi is None:
        epsilon_pbi = -1

    # Compute f-values.
    X_batch = np.array([x_val])
    out = {}
    zdt1_problem._evaluate(X_batch, out)
    f_val = out["F"][0]
    f1, f2 = f_val[0], f_val[1]

    data.append({
        "Point": label,
        "x": x_val,
        "f1": f1,
        "f2": f2,
        "APBI-KKTPM ": epsilon_A,
        "APBI Updated-KKTPM ": epsilon_A_updated,
        "PBI-KKTPM": epsilon_pbi
    })
    
    results.append((label, x_val, f1, f2, epsilon_A, epsilon_A_updated, epsilon_pbi))
    
    print(f"Point {label} -> x={x_val}, f1={f1:.6f}, f2={f2:.6f}, "
          f"APBI-KKTPM={epsilon_A:.6f}, APBI-KKTPM_Updated={epsilon_A_updated:.6f}, PBI-KKTPM={epsilon_pbi:.6f}")

# Create a DataFrame for easier inspection.
df = pd.DataFrame(data)
print("\nResults DataFrame:")
print(df)

# 8) Plot a bar chart comparing the three KKTPM measures.
labels = [item[0] for item in results]
epsilon_A_vals = [item[4] for item in results]
epsilon_A_updated_vals = [item[5] for item in results]
epsilon_pbi_vals = [item[6] for item in results]

x_indices = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x_indices - width, epsilon_A_vals, width, label='APBI-KKTPM')
rects2 = ax.bar(x_indices, epsilon_A_updated_vals, width, label='APBI-KKTPM_Updated')
rects3 = ax.bar(x_indices + width, epsilon_pbi_vals, width, label='PBI-KKTPM')

ax.set_ylabel('KKTPM Value')
ax.set_xticks(x_indices)
ax.set_xticklabels(labels, rotation=45)
ax.legend()
ax.set_title('Comparison of KKTPM Values for Table 2 Points')

plt.tight_layout()
plt.show()
# Out:
# ZDT1 (2D) Table 2 KKTPM Tests
# --------------------------------------
# F_val [1.0e-04 9.9e-01]
# diff [1.0e-04 9.9e-01]
# w_norm 1.0
# d1 0.99
# d2_vec [0.0001 0.    ]
# F_val [1.01000000e-04 9.89950124e-01]
# diff [1.01000000e-04 9.89950124e-01]
# w_norm 1.0
# d1 0.9899501243788791
# d2_vec [0.000101 0.      ]
# F_val [1.00000000e-04 9.90008955e-01]
# diff [1.00000000e-04 9.90008955e-01]
# w_norm 1.0
# d1 0.9900089550001012
# d2_vec [0.0001 0.    ]
# Grad phi: [-48.87562112   8.9550001 ]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.0001, -0.0, -0.9999, -1.0]
# Optimal u: [1.06783813e-11 8.95500061e+00 2.44402525e+01 5.19909391e-08]
# Optimal eps_k: 597.0872387787809
# Point A1 -> x=[0.0001 0.    ], f1=0.000100, f2=0.990000, APBI-KKTPM=1.000000, APBI-KKTPM_Updated=1.000000, PBI-KKTPM=597.087239
# F_val [1.00000000e-04 1.07955969e+00]
# diff [1.00000000e-04 1.07955969e+00]
# w_norm 1.0
# d1 1.0795596934910896
# d2_vec [0.0001 0.    ]
# F_val [1.01000000e-04 1.07950762e+00]
# diff [1.01000000e-04 1.07950762e+00]
# w_norm 1.0
# d1 1.079507621813907
# d2_vec [0.000101 0.      ]
# F_val [1.00000000e-04 1.07956865e+00]
# diff [1.00000000e-04 1.07956865e+00]
# w_norm 1.0
# d1 1.0795686503889956
# d2_vec [0.0001 0.    ]
# Grad phi: [-51.07167718   8.95689791]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.0001, -0.01, -0.9999, -0.99]
# Optimal u: [-2.45611185e-11  8.95599874e+00  2.55383906e+01 -8.69445350e-13]
# Optimal eps_k: 651.948722750126
# Point B1 -> x=[0.0001 0.01  ], f1=0.000100, f2=1.079560, APBI-KKTPM=1.000000, APBI-KKTPM_Updated=1.000000, PBI-KKTPM=651.948723
# F_val [1.0000000e-04 1.3483381e+00]
# diff [1.0000000e-04 1.3483381e+00]
# w_norm 1.0
# d1 1.3483380962103093
# d2_vec [0.0001 0.    ]
# F_val [1.01000000e-04 1.34827993e+00]
# diff [1.01000000e-04 1.34827993e+00]
# w_norm 1.0
# d1 1.348279931740813
# d2_vec [0.000101 0.      ]
# F_val [1.00000000e-04 1.34834706e+00]
# diff [1.00000000e-04 1.34834706e+00]
# w_norm 1.0
# d1 1.3483470576231917
# d2_vec [0.0001 0.    ]
# Grad phi: [-57.1644695    8.96141288]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.0001, -0.04, -0.9999, -0.96]
# Optimal u: [-1.55364072e-11  8.94708615e+00  2.85850942e+01 -4.52308475e-13]
# Optimal eps_k: 816.7808979686322
# Point C1 -> x=[0.0001 0.04  ], f1=0.000100, f2=1.348338, APBI-KKTPM=1.000000, APBI-KKTPM_Updated=1.000000, PBI-KKTPM=816.780898
# F_val [1.00000000e-04 1.52759033e+00]
# diff [1.00000000e-04 1.52759033e+00]
# w_norm 1.0
# d1 1.5275903263540092
# d2_vec [0.0001 0.    ]
# F_val [1.01000000e-04 1.52752843e+00]
# diff [1.01000000e-04 1.52752843e+00]
# w_norm 1.0
# d1 1.527528432335909
# d2_vec [0.000101 0.      ]
# F_val [1.00000000e-04 1.52759929e+00]
# diff [1.00000000e-04 1.52759929e+00]
# w_norm 1.0
# d1 1.5275992900920288
# d2_vec [0.0001 0.    ]
# Grad phi: [-60.8940181    8.96373802]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.0001, -0.06, -0.9999, -0.94]
# Optimal u: [-3.59515227e-11  8.93157489e+00  3.04500494e+01 -4.06879596e-13]
# Optimal eps_k: 926.8362616737752
# Point D1 -> x=[0.0001 0.06  ], f1=0.000100, f2=1.527590, APBI-KKTPM=1.000000, APBI-KKTPM_Updated=1.000000, PBI-KKTPM=926.836262
# F_val [1.00000000e-04 1.70688512e+00]
# diff [1.00000000e-04 1.70688512e+00]
# w_norm 1.0
# d1 1.706885122951396
# d2_vec [0.0001 0.    ]
# F_val [1.01000000e-04 1.70681971e+00]
# diff [1.01000000e-04 1.70681971e+00]
# w_norm 1.0
# d1 1.7068197116875237
# d2_vec [0.000101 0.      ]
# F_val [1.00000000e-04 1.70689409e+00]
# diff [1.00000000e-04 1.70689409e+00]
# w_norm 1.0
# d1 1.7068940886392627
# d2_vec [0.0001 0.    ]
# Grad phi: [-64.41126387   8.96568787]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.0001, -0.08, -0.9999, -0.92]
# Optimal u: [-4.46826147e-11  8.90866958e+00  3.22088465e+01 -1.66907401e-12]
# Optimal eps_k: 1036.9989325116326
# Point E1 -> x=[0.0001 0.08  ], f1=0.000100, f2=1.706885, APBI-KKTPM=1.000000, APBI-KKTPM_Updated=1.000000, PBI-KKTPM=1036.998933
# F_val [1.00000000e-04 1.79654638e+00]
# diff [1.00000000e-04 1.79654638e+00]
# w_norm 1.0
# d1 1.7965463759529263
# d2_vec [0.0001 0.    ]
# F_val [1.01000000e-04 1.79647928e+00]
# diff [1.01000000e-04 1.79647928e+00]
# w_norm 1.0
# d1 1.7964792751673588
# d2_vec [0.000101 0.      ]
# F_val [1.00000000e-04 1.79655534e+00]
# diff [1.00000000e-04 1.79655534e+00]
# w_norm 1.0
# d1 1.7965553425047314
# d2_vec [0.0001 0.    ]
# Grad phi: [-66.10078557   8.96655181]
# Grad g: [array([-1.,  0.]), array([ 0., -1.]), array([1., 0.]), array([0., 1.])]
# g_vals: [-0.0001, -0.09, -0.9999, -0.91]
# Optimal u: [1.78601634e-11 8.89451354e+00 3.30536722e+01 1.00850169e-12]
# Optimal eps_k: 1092.116889356198
# Point F1 -> x=[0.0001 0.09  ], f1=0.000100, f2=1.796546, APBI-KKTPM=1.000000, APBI-KKTPM_Updated=1.000000, PBI-KKTPM=1092.116889
#
# Results DataFrame:
#   Point               x      f1        f2  APBI-KKTPM   APBI Updated-KKTPM   \
# 0    A1   [0.0001, 0.0]  0.0001  0.990000            1                    1
# 1    B1  [0.0001, 0.01]  0.0001  1.079560            1                    1
# 2    C1  [0.0001, 0.04]  0.0001  1.348338            1                    1
# 3    D1  [0.0001, 0.06]  0.0001  1.527590            1                    1
# 4    E1  [0.0001, 0.08]  0.0001  1.706885            1                    1
# 5    F1  [0.0001, 0.09]  0.0001  1.796546            1                    1
#
#      PBI-KKTPM
# 0   597.087239
# 1   651.948723
# 2   816.780898
# 3   926.836262
# 4  1036.998933
# 5  1092.116889
